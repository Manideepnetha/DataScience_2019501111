# %%
import pandas as pd
import numpy as np

# %%
ratings = pd.read_csv("title-data.tsv", delimiter = '\t')
ratings.head(10)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1669
# 1  tt0000002            6.1       207
# 2  tt0000003            6.5      1392
# 3  tt0000004            6.2       123
# 4  tt0000005            6.2      2181
# 5  tt0000006            5.3       119
# 6  tt0000007            5.4       668
# 7  tt0000008            5.4      1838
# 8  tt0000009            6.0       154
# 9  tt0000010            6.9      6152

# %%
ratings = ratings[ratings["numVotes"] >= 10000]
ratings
# Out:
#             tconst  averageRating  numVotes
# 11       tt0000012            7.4     10544
# 298      tt0000417            8.2     43815
# 307      tt0000439            7.3     17242
# 1571     tt0004972            6.3     22620
# 1954     tt0006864            7.7     14155
# ...            ...            ...       ...
# 1106886  tt9866072            6.1     40179
# 1107751  tt9898836            9.9     14589
# 1107752  tt9898858            5.1     11421
# 1107838  tt9900782            8.5     10946
# 1107969  tt9906260            9.9     34134
#
# [10935 rows x 3 columns]

# %%
ratings.drop(["tconst"], axis = 1, inplace = True)
ratings
# Out:
#          averageRating  numVotes
# 11                 7.4     10544
# 298                8.2     43815
# 307                7.3     17242
# 1571               6.3     22620
# 1954               7.7     14155
# ...                ...       ...
# 1106886            6.1     40179
# 1107751            9.9     14589
# 1107752            5.1     11421
# 1107838            8.5     10946
# 1107969            9.9     34134
#
# [10935 rows x 2 columns]

# %%
ratings.to_csv("rankvsvotes.csv", index = False)

# %%
import matplotlib.pyplot as plt
plt.scatter(ratings["averageRating"], ratings["numVotes"], alpha=0.7)
plt.show()
